# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('..\learning\HistoricalData_1649402921205.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        23 non-null     object
#  1   Close/Last  23 non-null     object
#  2   Volume      23 non-null     int64
#  3   Open        23 non-null     object
#  4   High        23 non-null     object
#  5   Low         23 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.2+ KB

# %%
df.describe()
# Out:
#              Volume
# count  2.300000e+01
# mean   9.374430e+07
# std    1.474776e+07
# min    7.340179e+07
# 25%    8.103908e+07
# 50%    9.263315e+07
# 75%    1.014448e+08
# max    1.311483e+08

# %%
df.head()
# Out:
#          Date Close/Last    Volume     Open     High       Low
# 0  04/07/2022    $172.14  77594650  $171.16  $173.36   $169.85
# 1  04/06/2022    $171.83  89058780  $172.36  $173.63   $170.13
# 2  04/05/2022    $175.06  73401790   $177.5   $178.3  $174.415
# 3  04/04/2022    $178.44  76545980  $174.57  $178.49   $174.44
# 4  04/01/2022    $174.31  78751330  $174.03  $174.88   $171.94

# %%
df.tail(7)
# Out:
#           Date Close/Last     Volume      Open     High      Low
# 16  03/16/2022    $159.59  102300200   $157.05     $160  $154.46
# 17  03/15/2022    $155.09   92964300    $150.9  $155.57  $150.38
# 18  03/14/2022    $150.62  108732100   $151.45  $154.12   $150.1
# 19  03/11/2022    $154.73   96970100   $158.93  $159.28   $154.5
# 20  03/10/2022    $158.52  105342000    $160.2  $160.39  $155.98
# 21  03/09/2022    $162.95   91454910  $161.475  $163.41  $159.41
# 22  03/08/2022    $157.44  131148300   $158.82  $162.88   $155.8

# %%
df.isnull().sum()
# Out:
# Date          0
# Close/Last    0
# Volume        0
# Open          0
# High          0
# Low           0
# dtype: int64

# %% [markdown]
# Data Manipulation -- Sub setting

# %%
df = df[['Date', 'Close/Last']]
df.head()
# Out:
#          Date Close/Last
# 0  04/07/2022    $172.14
# 1  04/06/2022    $171.83
# 2  04/05/2022    $175.06
# 3  04/04/2022    $178.44
# 4  04/01/2022    $174.31

# %%
df = df.replace({'\$': ''}, regex = True)
df
# Out:
#           Date Close/Last
# 0   04/07/2022     172.14
# 1   04/06/2022     171.83
# 2   04/05/2022     175.06
# 3   04/04/2022     178.44
# 4   04/01/2022     174.31
# 5   03/31/2022     174.61
# 6   03/30/2022     177.77
# 7   03/29/2022     178.96
# 8   03/28/2022      175.6
# 9   03/25/2022     174.72
# 10  03/24/2022     174.07
# 11  03/23/2022     170.21
# 12  03/22/2022     168.82
# 13  03/21/2022     165.38
# 14  03/18/2022     163.98
# 15  03/17/2022     160.62
# 16  03/16/2022     159.59
# 17  03/15/2022     155.09
# 18  03/14/2022     150.62
# 19  03/11/2022     154.73
# 20  03/10/2022     158.52
# 21  03/09/2022     162.95
# 22  03/08/2022     157.44

# %%
df = df.astype({"Close/Last":float})
df['Date'] = pd.to_datetime(df.Date, format ="%m/%d/%Y" )
df.dtypes
# Out:
# Date          datetime64[ns]
# Close/Last           float64
# dtype: object

# %%
df.index = df['Date']
df.index
# Out:
# DatetimeIndex(['2022-04-07', '2022-04-06', '2022-04-05', '2022-04-04',
#                '2022-04-01', '2022-03-31', '2022-03-30', '2022-03-29',
#                '2022-03-28', '2022-03-25', '2022-03-24', '2022-03-23',
#                '2022-03-22', '2022-03-21', '2022-03-18', '2022-03-17',
#                '2022-03-16', '2022-03-15', '2022-03-14', '2022-03-11',
#                '2022-03-10', '2022-03-09', '2022-03-08'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
plt.plot(df['Close/Last'], label = 'AAPL Close Price History')

# %%
df = df.sort_index(ascending = True, axis = 0)
df
# Out:
#                  Date  Close/Last
# Date
# 2022-03-08 2022-03-08      157.44
# 2022-03-09 2022-03-09      162.95
# 2022-03-10 2022-03-10      158.52
# 2022-03-11 2022-03-11      154.73
# 2022-03-14 2022-03-14      150.62
# 2022-03-15 2022-03-15      155.09
# 2022-03-16 2022-03-16      159.59
# 2022-03-17 2022-03-17      160.62
# 2022-03-18 2022-03-18      163.98
# 2022-03-21 2022-03-21      165.38
# 2022-03-22 2022-03-22      168.82
# 2022-03-23 2022-03-23      170.21
# 2022-03-24 2022-03-24      174.07
# 2022-03-25 2022-03-25      174.72
# 2022-03-28 2022-03-28      175.60
# 2022-03-29 2022-03-29      178.96
# 2022-03-30 2022-03-30      177.77
# 2022-03-31 2022-03-31      174.61
# 2022-04-01 2022-04-01      174.31
# 2022-04-04 2022-04-04      178.44
# 2022-04-05 2022-04-05      175.06
# 2022-04-06 2022-04-06      171.83
# 2022-04-07 2022-04-07      172.14

# %%
data = pd.DataFrame(index=range(0,len(df)), columns=['Date', 'Close'])

for i in range(0, len(data)):
    data["Date"][i]=df['Date'][i]
    data["Close"][i]=df['Close/Last'][i]
data
# Out:
#                    Date   Close
# 0   2022-03-08 00:00:00  157.44
# 1   2022-03-09 00:00:00  162.95
# 2   2022-03-10 00:00:00  158.52
# 3   2022-03-11 00:00:00  154.73
# 4   2022-03-14 00:00:00  150.62
# 5   2022-03-15 00:00:00  155.09
# 6   2022-03-16 00:00:00  159.59
# 7   2022-03-17 00:00:00  160.62
# 8   2022-03-18 00:00:00  163.98
# 9   2022-03-21 00:00:00  165.38
# 10  2022-03-22 00:00:00  168.82
# 11  2022-03-23 00:00:00  170.21
# 12  2022-03-24 00:00:00  174.07
# 13  2022-03-25 00:00:00  174.72
# 14  2022-03-28 00:00:00   175.6
# 15  2022-03-29 00:00:00  178.96
# 16  2022-03-30 00:00:00  177.77
# 17  2022-03-31 00:00:00  174.61
# 18  2022-04-01 00:00:00  174.31
# 19  2022-04-04 00:00:00  178.44
# 20  2022-04-05 00:00:00  175.06
# 21  2022-04-06 00:00:00  171.83
# 22  2022-04-07 00:00:00  172.14
